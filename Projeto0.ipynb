# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/base2.xlsm', header=1)
df = df.drop(["Unnamed: 3", "Unnamed: 22", "Unnamed: 23", "Unnamed: 24", "Unnamed: 25", "Unnamed: 26", "Unnamed: 27", "Unnamed: 28", "Unnamed: 29", "Unnamed: 30", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 16", "Unnamed: 12", "Unnamed: 17", "Unnamed: 18", "Unnamed: 19", "Unnamed: 20", "Unnamed: 21", "Unnamed: 31", "Custo total", "STATS"], axis=1)
display(df)
# Out:
#      Marca   Cód.                                          Descrição Estoq.  \
# 0       LG   2247  Ar Cond. LG Dual Inverter Voice S4Q09WA51C 09 ...      4
# 1       LG   2274  Ar Cond. LG Dual Inverter Voice S4NQ09AA31B 09...    594
# 2       LG   2248   Ar Cond. LG Dual Inverter Voice S4W09WA51A 09...      1
# 3       LG   2275  Ar Cond. LG Dual Inverter Voice S4NW09AA31B 09...    285
# 4       LG   2249   Ar Cond. LG Dual Inverter Voice S4Q12JA31C 12...     14
# ..     ...    ...                                                ...    ...
# 305  Trane  19811  Ar Cond. Trane Dutado Inverter 4MXD6518G1000AA...     -
# 306  Trane  19812  \tAr Cond. Trane Dutado Inverter 4MXD6524G1000...     -
# 307  Trane  19813  \tAr Cond. Trane Dutado Inverter 4MXD6536G1000...      1
# 308  Trane  19814  Ar Cond. Trane Dutado Inverter 4MXD6548G1000AA...     -
# 309  Trane  19815  Ar Cond. Trane Dutado Inverter 4MXD6560G1000AA...     -
#
# ...

# %%
df = df.dropna()
display(df.info())

display(df.describe().round(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198 entries, 0 to 309
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Marca                   198 non-null    object
#  1   Cód.                    198 non-null    object
#  2   Descrição               198 non-null    object
#  3   Estoq.                  198 non-null    object
#  4   Media de Venda Semanal  198 non-null    float64
#  5   Valor a vista           198 non-null    object
#  6   Valor 10x               198 non-null    object
#  7   ML                      198 non-null    float64
#  8   MB                      198 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 15.5+ KB
# None
#        Media de Venda Semanal      ML
# count                  198.00  198.00
# mean                     5.56    0.00
# std                     12.16    0.09
# min                      0.00   -0.34
# ...

# %%
qntPorMarcas = df["Marca"].value_counts()
display(qntPorMarcas)
qntMarcasPerc = df["Marca"].value_counts(normalize=True)
display(qntMarcasPerc)
# Out:
# Marca
# LG         56
# Daikin     39
# Midea      36
# Gree       25
# Trane      20
# Carrier    19
# Samsung     2
# Agratto     1
# Name: count, dtype: int64
# Marca
# LG         0.282828
# Daikin     0.196970
# Midea      0.181818
# Gree       0.126263
# Trane      0.101010
# Carrier    0.095960
# Samsung    0.010101
# Agratto    0.005051
# Name: proportion, dtype: float64

# %%
import plotly.express as px


graf = px.histogram(df, x="Valor a vista", color="Descrição")
graf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
graf = px.histogram(df, x="Media de Venda Semanal", color="Descrição")
graf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
graf = px.histogram(df, x="Estoq.", color="Descrição")
graf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for coluna in df:
  graf = px.histogram(df, x=coluna, color="Descrição")
  graf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
